# %%
# %matplotlib inline
import numpy as np
import pandas as pd
df = pd.read_csv("PastHires.csv")
df.head(11)# to display from beginning
# Out:
#     Years Experience Employed?  Previous employers Level of Education  \
# 0                 10         Y                   4                 BS
# 1                  0         N                   0                 BS
# 2                  7         N                   6                 BS
# 3                  2         Y                   1                 MS
# 4                 20         N                   2                PhD
# 5                  0         N                   0                PhD
# 6                  5         Y                   2                 MS
# 7                  3         N                   1                 BS
# 8                 15         Y                   5                 BS
# 9                  0         N                   0                 BS
# 10                 1         N                   1                PhD
#
#    Top-tier school Interned Hired
# 0                N        N     Y
# 1                Y        Y     Y
# ...

# %%
df.tail(6) #display 6 from end
# Out:
#     Years Experience Employed?  Previous employers Level of Education  \
# 7                  3         N                   1                 BS
# 8                 15         Y                   5                 BS
# 9                  0         N                   0                 BS
# 10                 1         N                   1                PhD
# 11                 4         Y                   1                 BS
# 12                 0         N                   0                PhD
#
#    Top-tier school Interned Hired
# 7                N        Y     Y
# 8                N        N     Y
# 9                N        N     N
# 10               Y        N     N
# 11               N        Y     Y
# 12               Y        N     Y

# %%
df.shape # give you no. of rows and columns
# Out:
# (13, 7)

# %%
df.size #total matrix
# Out:
# 91

# %%
df.columns #for name of columns
# Out:
# Index(['Years Experience', 'Employed?', 'Previous employers',
#        'Level of Education', 'Top-tier school', 'Interned', 'Hired'],
#       dtype='object')

# %%
df['Employed?'] #display particular column
# Out:
# 0     Y
# 1     N
# 2     N
# 3     Y
# 4     N
# 5     N
# 6     Y
# 7     N
# 8     Y
# 9     N
# 10    N
# 11    Y
# 12    N
# Name: Employed?, dtype: object

# %%
df['Hired'][:7] #indexing in column
# Out:
# 0    Y
# 1    Y
# 2    N
# 3    Y
# 4    N
# 5    Y
# 6    Y
# Name: Hired, dtype: object

# %%
df[['Hired','Previous employers', 'Level of Education']] #display more than one column
# Out:
#    Hired  Previous employers Level of Education
# 0      Y                   4                 BS
# 1      Y                   0                 BS
# 2      N                   6                 BS
# 3      Y                   1                 MS
# 4      N                   2                PhD
# 5      Y                   0                PhD
# 6      Y                   2                 MS
# 7      Y                   1                 BS
# 8      Y                   5                 BS
# 9      N                   0                 BS
# 10     N                   1                PhD
# 11     Y                   1                 BS
# 12     Y                   0                PhD

# %%
df[['Hired','Previous employers', 'Level of Education']] [:7] #indexing in more than one column
# Out:
#   Hired  Previous employers Level of Education
# 0     Y                   4                 BS
# 1     Y                   0                 BS
# 2     N                   6                 BS
# 3     Y                   1                 MS
# 4     N                   2                PhD
# 5     Y                   0                PhD
# 6     Y                   2                 MS

# %%
df.sort_values(['Previous employers']) #sorting in ascending order
# Out:
#     Years Experience Employed?  Previous employers Level of Education  \
# 1                  0         N                   0                 BS
# 5                  0         N                   0                PhD
# 9                  0         N                   0                 BS
# 12                 0         N                   0                PhD
# 3                  2         Y                   1                 MS
# 7                  3         N                   1                 BS
# 10                 1         N                   1                PhD
# 11                 4         Y                   1                 BS
# 4                 20         N                   2                PhD
# 6                  5         Y                   2                 MS
# 0                 10         Y                   4                 BS
# 8                 15         Y                   5                 BS
# ...

# %%
h = df['Hired'].value_counts() 
h
# Out:
# Y    9
# N    4
# Name: Hired, dtype: int64

# %%
h.plot(kind='bar') #for ploting histogram
